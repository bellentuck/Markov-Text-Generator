# %%
import random
import re
import string

# %% [markdown]
# ## 1. Read in a file

# %%
def read_file(filename):
    """Parses a text file.
    """
    f = open(filename, 'r')
    f = f.readlines()
    #f.close() --?
    return f

# %% [markdown]
# Let's read in a file.

# %%
markov_input_text = read_file('/Users/Ben/Documents/tractatus.txt')

# %%
type(markov_input_text)
# Out:
# list

# %% [markdown]
# ##2. From file, get initial chunk candidates of a given
#
# ### (a) Level
# - What's our base unit? Could be words, characters, integers, etc.
# - We're working with text data, and we don't want to scramble too much--so: words
#
# ### (b) Order
# - *How many* members of a given level are to make up a chunk?
# - For us, order-n will progress by n-word chunks (these are the 'n-grams' Michael will be presenting on tomorrow! get psyched)

# %% [markdown]
# ###2a. get candidates

# %%
def get_candidates(f):
    #f = read_file(f)
    
    candidates = ''
    while candidates == '' or candidates == '\n':
        for index, line in enumerate(f):
            
            #generate random numbers less than index + n
            uno = random.randrange(index + 2)  
            dos = random.randrange(index + 22)
            #probably not the only way to do this
            
            if uno == dos:
                candidates += line
    
    #candidates = candidates.split() #split text into chunks -- other ways to do this?
    
    print "initial candidate lines:\n", candidates
    return candidates

# %% [markdown]
# Re: line 7: a list is analagous to a Pandas series of indices + elements:

# %%
a = ['line 1','line 2','line 3']
print type(a)

for index, line in enumerate(a):
    print index, line
# Out:
# <type 'list'>
# 0 line 1
# 1 line 2
# 2 line 3

# %%
import pandas as pd
b = pd.Series(['line 1','line 2','line 3'])
print type(b)

print b
# Out:
# <class 'pandas.core.series.Series'>
# 0    line 1
# 1    line 2
# 2    line 3
# dtype: object

# %% [markdown]
# Back to Markov:
#
# Let's meet our candidates.

# %%
candies = get_candidates(markov_input_text)
candies
# Out:
# initial candidate lines:
# expressed--the more the nail has been hit on the head--the greater will be
# 2.15 The fact that the elements of a picture are related to one another in
# true, their truth could only be the result of a fortunate accident.
# 'expressed--the more the nail has been hit on the head--the greater will be\n2.15 The fact that the elements of a picture are related to one another in\ntrue, their truth could only be the result of a fortunate accident.\n'

# %% [markdown]
# ###2b. split candidates str into order-1 chunks
#
# Now let's split our candidate lines into basic, order-1 chunks, in order to arrive at a list of candidates.

# %%
def split_text_into_chunks(candidates):
    candidates = candidates.split()
    return candidates

# %%
candidates = split_text_into_chunks(candies)
candidates
# Out:
# ['expressed--the',
#  'more',
#  'the',
#  'nail',
#  'has',
#  'been',
#  'hit',
#  'on',
#  'the',
#  'head--the',
#  'greater',
#  'will',
#  'be',
#  '2.15',
#  'The',
#  'fact',
#  'that',
#  'the',
#  'elements',
#  'of',
#  'a',
#  'picture',
#  'are',
#  'related',
#  'to',
#  'one',
#  'another',
#  'in',
#  'true,',
#  'their',
#  'truth',
#  'could',
#  'only',
#  'be',
#  'the',
#  'result',
#  'of',
#  'a',
#  'fortunate',
#  'accident.']

# %% [markdown]
# - How could we resolve the double-dash issue?
# - How might we split if our base unit were characters?

# %% [markdown]
# ###2c. from candidates, select chunk at which to begin Markovized text
#
# - Chunk is to be of appropriate order and level.

# %%
def select_chunk(candidates, order=1, level=False):

    text = [ ]

    start = random.randint(0, len(candidates) - order)
    chunk = candidates[start]
    
    if order == 1:
        pass
    else:
        for i in range(1, order):  
            chunk = chunk + ' ' + candidates[start + i]
    text.append(chunk) 
    print "initial chunk: ", text
    return text

# %%
beginning = select_chunk(candidates)
beginning
# Out:
# initial chunk:  ['the']
# ['the']

# %% [markdown]
# #3. Get more chunks
#
# - From our initial chunk, `beginning`, we're going to generate a subsequent chunk of the same level and order. (3a-d)
#
# - We'll iterate (loop) this process: new chunk generation "memorylessly" based solely on a single, directly preceding chunk. We'll stop when our chunked-together text attains a given length, returning `text` as a string. (3e)

# %% [markdown]
# ###3a. check for a possible match

# %%
def check_for_possible_match(chunklist, line, order, n):
    candidate_str = ''
    if line[n] == chunklist[-1]:     
        candidate_str += line[n+1]  # keep track of chunk following latest text-chunk                  
        if order == 1:
            pass
        else:
            for i in range(2, order+1):
                candidate_str += ' ' + line[n+i]              
    return candidate_str

# %% [markdown]
# ###3b. gather possible matches together

# %%
def gather_next_chunks(f, chunklist, order):
    candidates = []
    acceptable_characters = string.letters + string.digits + ' '

    for line in enumerate(f):  
        if chunklist[-1] in line[1]:  # check for a possible match 
            line = line[1].split()
            for n in range(0, len(line) - order):             
                candidate_str = check_for_possible_match(chunklist, line, order, n)
                candidate_str = filter(lambda x: x in acceptable_characters, candidate_str)                                                           
                candidates.append(candidate_str)
                    
    return candidates

# %% [markdown]
# ###3c. filter out possible matches that are empty strings

# %%
def edit_chunks(candidates):
    candidates_edited = []
    for i in candidates:
        if i != '':       # empty strings had been a problem
            candidates_edited.append(i)
    return candidates_edited

# %% [markdown]
# ###3d. select a single next chunk from the list of possible matches

# %%
def pick_next_chunk(candidates, next_chunk): 
    if candidates != []:
        r = random.randint(0, len(candidates) - 1)
        next_chunk = candidates[r]
    return next_chunk

# %% [markdown]
# ###3e. iterate through this process

# %%
def chunk_seq(f, text, order=1, length=50):
        """Generates a string of chuncks from an initial chunk.
        
        Input: 
        f = lines in file
        text = list containing initial chunk
        order
        length
        
        Output: 
        markov = a string, wordcount == length, of chunks
        """
        next_chunk = text[-1]
        chunklist = next_chunk.split()
        
        while len(text) * order < length:
            candidates = gather_next_chunks(f, chunklist, order) #1
            candidates_edited = edit_chunks(candidates)
            #print candidates_edited
            next_chunk = pick_next_chunk(candidates_edited, next_chunk)
            text.append(next_chunk)
        
        markov = ' '.join(text)
        return markov

# %% [markdown]
# - I've cheated a bit in terms of how I'm using `-1` instead of `-order`. How might we think about fixing this? At what point is it worth fixing? When might a "purer" transformation from chunk to chunk be desirable?
# - what if there's only one instance of a chunk in a text?
# - How might we optimize `check_for_possible_match` and `gather_next_chunks`?

# %% [markdown]
# #Finally...

# %%
chunk_seq(markov_input_text, beginning)
# Out:
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# ['thoughts', 'problems', 'reason', 'logic', 'book', 'aim', 'book', 'expression', 'limit', 'limit', 'other', 'limit', 'reason', 'thoughts', 'stimulation', 'first', 'better', 'thoughts', 'nail', 'headthe', 'accomplishment', 'taskMay', 'other', 'truth', 'thoughts', 'final', 'problems', 'second', 'of', 'case', 'totality', 'facts', 'totality', 'case', 'case', 'world', 'case', 'case', 'same', 'casea', 'existence', 'possibility', 'state', 'beginning', 'province', 'possibility', 'possibility', 'object', 'same', 'thing', 'visual', 'sense', 'possibility', 'form', 'propositions', 'substance', 'world', 'world', 'real', 'world', 'configuration', 'same', 'only', 'others', 'other', 'case', 'world', 'unalterable', 'subsistent', 'same', 'links', 'structure', 'state', 'possibility', 'structures', 'world', 'existence', 'existence', 'existence', 'world', 'existence', 'elements', 'picture', 'elements', 'picture', 'representatives', 'elements', 'structure', 'possibility', 'pictorial', 'picture', 'possibility', 'same', 'elements', 'picture', 'endpoints', 'graduating', 'pictorial', 'feelers', 'pictures', 'picture', 'one', 'other', 'way', 'form', 'same', 'other', 'world', 'possibility', 'situation', 'picture', 'world', 'possibility', 'situation', 'laws', 'laws', 'coordinates', 'laws', 'laws', 'thought', 'senses', 'perceptible', 'sense', 'proposition', 'sign', 'world', 'possibility', 'content', 'form', 'content', 'propositional', 'objects', 'thought', 'same', 'propositional', 'requirement', 'complex', 'complex', 'propositions', 'proposition', 'notation', 'signs', 'definitions', 'way', 'same', 'other', 'meanings', 'nexus', 'mark', 'forms', 'propositions', 'common', 'general', 'expression', 'propositions', 'expression', 'limiting', 'expression', 'resulting', 'meaning', 'original', 'signs', 'nature', 'pro', 'variable', 'variable', 'only', 'stipulation', 'description', 'same', 'same', 'two', 'sign', 'signifying', 'same', 'same', 'word', 'copula', 'proposition', 'first', 'proper', 'last', 'most', 'same', 'point', 'meaning', 'meaning', 'description', 'meaning', 'rules', 'whole', 'sign', 'prototype', 'function', 'outer', 'inner', 'inner', 'form', 'outer', 'form', 'letter', 'two', 'letter', 'particular', 'proposition', 'same', 'same', 'real', 'case', 'essence', 'individual', 'possibility', 'essence', 'world', 'symbols', 'rules', 'following', 'notation', 'way', 'possibility', 'sign', 'mere', 'constituents', 'existence', 'proposition', 'logical', 'whole', 'whole', 'ability', 'human', 'logic', 'outward', 'clothing', 'form', 'thought', 'clothing', 'form', 'understanding', 'propositions', 'propositions', 'logic', 'same', 'question', 'good', 'beautiful', 'deepest', 'service', 'printed', 'reality', 'ordinary', 'form', 'sign', 'essence', 'use', 'musical', 'written', 'same', 'world', 'two', 'fairytale', 'musician', 'symphony', 'score', 'groove', 'gramophone', 'first', 'score', 'inner', 'law', 'symphony', 'language', 'rule', 'language', 'logic', 'essential', 'facts', 'fact', 'sense', 'situation', 'help', 'case', 'one', 'other', 'constituents', 'same', 'essence', 'situation', 'connexion', 'whole', 'principle', 'logical', 'logic', 'proposition', 'situation', 'same', 'scope', 'generalitysign', 'argumentplacesfor', 'identity', 'necessary', 'same', 'idealists', 'seeing', 'multiplicity', 'facts', 'true', 'false', 'new', 'signs', 'same', 'sign', 'same', 'concept', 'shape', 'spot', 'sheet', 'fact', 'fact', 'sheet', 'supposition', 'sense', 'proposition', 'point', 'paper', 'verb', 'logical', 'negated', 'negated', 'help', 'negated', 'latters', 'existence', 'whole', 'whole', 'natural', 'natural', 'natural', 'logical', 'clarification', 'philosophy', 'study', 'philosophy', 'much', 'whole', 'world', 'logical', 'object', 'same', 'same', 'case', 'same', 'source', 'confusion', 'propositions', 'relevant', 'sense', 'shifting', 'shifting', 'words', 'situation', 'answer', 'vexed', 'numberseries', 'series', 'same', 'source', 'confusion', 'whole', 'very', 'sign', 'characteristics', 'concept',  ...
# 'the operation result help problems one innermost totality logic bracketed two logical unsubstantial logical picture variable symbol construction fairytale other shifting key form combination situation soulthe generality whole limits understanding same general terms thought one fact general propositions former great book subject result description mark form propositions righthand world operation'

# %%
markov = chunk_seq(markov_input_text, beginning)
markov
# Out:
# 'the operation result help problems one innermost totality logic bracketed two logical unsubstantial logical picture variable symbol construction fairytale other shifting key form combination situation soulthe generality whole limits understanding same general terms thought one fact general propositions former great book subject result description mark form propositions righthand world operation'

# %%
beginning = select_chunk(candidates)
chunk_seq(markov_input_text, beginning)
# Out:
# initial chunk:  ['only']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# ['by', 'be', 'mention', 'determine', 'by', 'distinction', 'it', 'be', 'speak', 'in', 'in', 'with', 'thing', 'the', 'one', 'point', 'they', 'substantives', 'in', 'in', 'in', 'one', 'one', 'in', 'to', 'determinate', 'what', 'from', 'possible', 'if', 'in', 'of', 'one', 'by', 'in', 'p', 'general', 'because', 'be', 'the', 'one', 'one', 'one', 'be', 'a', 'things', 'a', 'because', 'as', 'glance', 'what', 'in', 'it', 'must', 'be', 'the', 'tautologies', 'because', 'in', 'talk', 'connexions', 'with', 'by', 'a', 'necessity', 'be', 'necessity', 'impossibility', 'to', 'the', 'is', 'to', 'where', 'where', 'where', 'strictly']
# 'only in in one be by be in distinction to to with glance where the mention be point mention p a must a impossibility because in one be impossibility in a be the where to is glance it in to point p as is one one they from the one'

# %% [markdown]
# ##order-2

# %%
new_candidates = get_candidates(markov_input_text)
new_candidates = split_text_into_chunks(new_candidates)
new_beginning = select_chunk(new_candidates, order=2)
chunk_seq(markov_input_text, new_beginning, order=2)
# Out:
# initial candidate lines:
#
#
# itself, would be illegitimate.) In a certain sense, we cannot make mistakes
# 5.557 The application of logic decides what elementary propositions there
#
# initial chunk:  ['decides what']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# ['can be', 'cannot be', 'I have', 'is the', 'constitute this', 'subsists independently', 'is the', 'is unalterable', 'is changing', 'it depicts', 'it depicts', 'it depicts', 'this means', 'made it', 'they are', 'is signified', 'can be', 'would be', 'is superficially', 'is essential', 'all propositions', 'all symbols', 'is common', 'is common', 'its meaning', 'the logic', 'they represent', 'they are', 'constitutes the', 'is the', 'we now', 'was being', 'they signify', 'Pp signified', 'circumstances I', 'black and', 'is affirmed', 'is negated', 'can be', 'cannot be', 'can be', 'cannot be', 'Frege and', 'the schemata', 'they say', 'is essential', 'is not', 'is essential', 'propositions I', 'is known', 'has to', 'the bases', 'p said', 'one might', 'all propositions', 'is common', 'is common', 'is common', 'numbers And', 'there must', 'is important', 'we ourselves', 'elementary propositions', 'elementary propositions', 'we cannot', 'the solipsist', 'is common', 'the logical', 'we wish', 'we do', 'we want', 'they express', 'they mean', 'does tell', 'the net', 'the law', 'if I', 'can be', 'is higher', 'constituted that', 'is mystical', 'can be']
# 'decides what there must black and is affirmed can be cannot be is essential the logic is higher the net the net I have is negated they are its meaning made it is not we do the logic the law is common it depicts can be the net is changing'

# %% [markdown]
# #order-3

# %%
newer_candidates = get_candidates(markov_input_text)
newer_candidates = split_text_into_chunks(newer_candidates)
newer_beginning = select_chunk(newer_candidates, order=3)
chunk_seq(markov_input_text, newer_beginning, order=3)
# Out:
# initial candidate lines:
#
# I am not mistaken in this belief, then the second thing in which the of
# follow from them come true. And similarly he could not create a world in
#
# initial chunk:  ['not mistaken in']
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# ['itor at least', 'order to be', 'language that the', 'two things the', 'it and on', 'this belief then', 'which the of', 'logical space are', 'a state of', 'states of affairs', 'the province of', 'states of affairs', 'so far as', 'two different roles', 'a space of', 'infinite space A', 'the visual field', 'states of affairs', 'common in which', 'which case it', 'a determinate relation', 'which objects are', 'a state of', 'logical space the', 'a determinate way', 'the same way', 'this way also', 'a picture and', 'common with reality', 'order to be', 'common with reality', 'order to be', 'common with what', 'language anything that', 'geometry to represent', 'its projective relation', 'its elements the', 'a determinate relation', 'writing or print', 'a printed proposition', 'a certain relation', 'such a way', 'propositions are called', 'a situation corresponds', 'the propositional sign', 'an internal relation', 'the propositions in', 'the same manner', 'the nexus of', 'this form the', 'a proposition All', 'it that have', 'propositions in what', 'what is superficially', 'a superficially similar', 'itself that is', 'that case there', 'a proposition is', 'common And similarly', 'a symbol is', 'common Thus one', 'our notations this', 'philosophy again and', 'a symbol is', 'the following way', 'common that for', 'a different proposition', 'logical space The', 'coordination The logical', 'fact not problems', 'the ordinary sense', 'musical notation For', 'the same internal', 'the logic of', 'the same way', 'so far as', 'so far as', 'the situation that', 'front of fxfor', 'virtue of being', 'the true way', 'the false way', 'a certain way', 'the new way', 'reality corresponds to', 'a proposition is', 'order to be', 'order to be', 'what circumstances I', 'itself shows that', 'the clarification of', 'most cases they', 'doing so to', 'common with reality', 'order to be', 'language language cannot', 'language we cannot', 'both of them', 'which everything is', 'the case of', 'the same sense', 'order to indicate', 'the propositions that', 'which we speak', 'this relation Here', 'language by means', 'one of these', 'the same sense', 'the very sign', 'conceptual notation by', 'a different way', 'conceptual notation the', 'which they want', 'logic and hence', 'the nexus of', 'which they have', 'which a proposition', 'the schema The', 'Pp etc then', 'the works of', 'a scheme is', 'the lefthand pair', 'the righthand pair', 'the second a', 'opposite directions to', 'any representational relation', 'the positive sense', 'which there is', 'the theory of', 'certain relations to', 'such a way', 'a certain sense', 'Pp however p', 'series That is', 'a schema of', 'those of the', 'the sense of', 'which certain propositions', 'which all the', 'relations in which', 'which the forms', 'a single proposition', 'this case by', 'the works of', 'the causal nexus', 'the impossibility of', 'the future We', 'no way justifies', 'common with another', 'common with one', 'the proposition r', 'the proposition s', 'columns in which', 'common with one', 'this way that', 'internal relations to', 'a logically meaningful', 'a variable it', 'common is just', 'a general way', 'this way that', 'PPp  PPp', 'which a truthfunction', 'the same way', '431 have a', '4442 expresses a', 'the sense in', 'the definition of', 'such a case', 'some sense negation', 'affirmation Does PPp', 'all the combinations', 'which it ever', 'propositions of the', 'both cases and', 'the same way', 'both cases In', 'brackets or in', 'a footnote with', 'Russell and Whiteheads', 'fact illicit But', 'logic stand in', 'need of justification', 'logic There are', 'which the answers', 'fact significant that', 'advance about the', 'itself For fa', 'logic is also', 'logic only because', 'practice its point', 'a signlanguage mean', 'an entirely different', 'the two cases', 'the righthand pair', 'the brackets Eg', 'which case we', 'an infinitely fine', 'the proposition Pp', 'Pp it is', 'common with one', 'Russells no ...
# 'not mistaken in a proposition All the logic of the same way which certain propositions which they have opposite directions to no way justifies this way he a certain relation philosophy again and language anything that fact significant that language language cannot front of fxfor common in which itself the whole'

# %% [markdown]
# #order-4

# %%
newest_candidates = get_candidates(markov_input_text)
newest_candidates = split_text_into_chunks(newest_candidates)
newest_beginning = select_chunk(newest_candidates, order=4)
chunk_seq(markov_input_text, newest_beginning, order=4)
# Out:
# initial candidate lines:
# another.
# picture of our speech. And yet these sign-languages prove to be pictures,
#
# 5.47 It is clear that whatever we can say in advance about the form of all
#
# initial chunk:  ['sign-languages prove to be']
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# ['understood only by someone', 'said at all can', 'said clearly and what', 'able to think what', 'in language that the', 'the case or not', 'a sort of accident', 'situated in infinite space', 'red must have some', 'resolved into a statement', 'objects if the world', 'a picture it must', 'something identical in a', 'a picture of the', 'able to depict itcorrectly', 'of anything illogical since', 'said that God could', 'contrary to the laws', 'represented by us spatially', 'described but not given', 'expressed in such a', 'named Signs are their', 'possible is the requirement', 'right or wrong A', 'nonsensical if the complex', 'seen from an indeterminateness', 'dissected any further by', 'anatomized by means of', 'explained by means of', 'constant and everything else', 'dependent on the meaning', 'perceived of a symbol', 'possible to establish logical', 'seen that Russell must', 'wrong because he had', 'contained in itself that', 'its own argument is', 'a proposition FFfx in', 'unessential to a name', 'unimportant but it is', 'translatable into any other', 'substituted for any of', 'disclosed by the possibility', 'a picture of the', 'explained to us if', 'exactly as many distinguishable', 'adequate we should not', 'adequate either we should', 'adequate we should not', 'able to establish the', 'true or false only', 'overlooked that a proposition', 'falseNo For a proposition', 'able to sayp is', 'related to the logical', 'thought and in doing', 'thought It must set', 'said by presenting clearly', 'thought at all can', 'put into words can', 'put clearly 412 Propositions', 'able to represent it', 'able to represent logical', 'able to station ourselves', 'shown cannot be said', 'bed a feature of', 'just as nonsensical to', 'represented by means of', 'to say 2 ', 'the answer to such', 'substituted for the sign', 'capable of translating each', 'true Thus  is', 'included in its descriptionfor', 'the most general form', 'quite possible to choose', 'understood unless the sense', 'arranged in series That', 'set out in a', 'gathered only from the', 'the number of Ts', 'gathered from the above', 'done to the one', 'variables that give expression', 'confused with each other', 'its own argument whereas', 'produced by double negation', 'incorrect The construction of', 'introduced first for one', 'given since the procedure', 'no distinction between the', 'a realm in which', 'able to say all', 'illegitimate In a certain', 'because we have failed', 'signified but rather of', 'possible to find an', 'in it a rule', 'manifest in our symbols', 'constructed with that of', 'possible to express a', 'solved at this point', 'equally true if in', 'in front and vice', 'possible to decide it', 'a logic even if', 'a logic given that', 'decidedBy experience There is', 'completely arbitrary to give', 'possible to answer a', 'in order that something', 'that which makes it', 'a hierarchy of the', 'the case since it', 'said  but makes', 'mentioned in that book', 'other than it is', 'other than it is', 'seen that solipsism when', 'generated out of another', 'a remarkable fact that', 'anything but obvious just', 'that the truth of', 'called a zeromethod In', 'confirmed by experience any', 'irrefutable by any possible', 'unconfirmable by any possible', 'subject to laws of', 'accidentally valid for all', 'tautological just as well', 'called essential in contrast', 'the result of a', 'indicated by the fact', 'altogether too remarkable if', 'proved logically from others', 'so In logic every', 'substituted for one another', 'substituted for one another', 'seen from the two', 'perceived without its being', 'compared with the facts', 'able to assert anything', 'given the answer that', 'a law of logic', 'a law of least', 'able to write down', 'able to write down', 'described completely by a', 'of the completely general', 'given a priori Laws', 'put in the following', 'found And if such', 'found we can regard', 'made to coincide exists', 'made to coincide unless', 'made to coin ...
# 'sign-languages prove to be quite possible to choose bed a feature of that which makes it bed a feature of red must have some gathered only from the seen from the two the following to say able to depict itcorrectly a picture of the a logic even if a picture of the'

# %% [markdown]
# Testing

# %%
test_candidates = get_candidates(markov_input_text)
test_candidates = split_text_into_chunks(test_candidates)
test_beginning = select_chunk(test_candidates, order=5)
#print type(test_beginning)
test = chunk_seq(markov_input_text, test_beginning, order=5)
print test
# Out:
# initial candidate lines:
#
# outward form of the clothing is not designed to reveal the form of the
#
# 5.251 A function cannot be its own argument, whereas an operation can take
#
# initial chunk:  ['is not designed to reveal']
# is not designed to reveal is not designed to reveal is not designed to reveal is not designed to reveal is not designed to reveal is not designed to reveal is not designed to reveal is not designed to reveal is not designed to reveal is not designed to reveal

# %% [markdown]
# Original (way way way too long) chunk_seq function

# %%
def chunk_seq(f, text, order=1, length=50):
        """Generates a string of chuncks from an initial chunk.
        
        Input: 
        f = lines in file
        text = list containing initial chunk
        order
        length
        
        Output: 
        markov = a string, wordcount == length, of chunks
        """
        next_chunk = text[-1]
        chunklist = next_chunk.split()
        #text = text.split()
        acceptable_characters = string.letters + string.digits + ' '

        while len(text) * order < length:
            
            ########### I. Gather possible next chunks ###########
            candidates = []
            for line in enumerate(f):   
                if chunklist[-1] in line[1]:  # check for a possible match 
                    line = line[1].split()
                    
                    
                    for n in range(0, len(line) - order):
                        candidate_str = ''
                        if line[n] == chunklist[-1]:     
                            candidate_str += line[n+1]  # keep track of chunk following latest text-chunk                  
                            if order == 1:
                                pass
                            else:
                                for i in range(2, order+1):
                                    candidate_str += ' ' + line[n+i]              
                                    
                        candidate_str = filter(lambda x: x in acceptable_characters, candidate_str)                                                           
                        candidates.append(candidate_str)
                        
            
            ########### II. Edit chunks ###########
            candidates_edited = []
            for i in candidates:
                if i != '':       # empty strings had been a problem
                    candidates_edited.append(i)
            print candidates_edited
            
             
            ########### III. Pick next chunk ###########
            #if candidates_edited == []:
                
                #next_chunk = text[-order:] #if no future instances, we are to append last order in previous 
            if candidates_edited != []:
                r = random.randint(0, len(candidates_edited) - 1)
                next_chunk = candidates_edited[r]
            text.append(next_chunk)
                #print next_chunk
            
                
        markov = ' '.join(text)
        return markov
